-- %%
CREATE TABLE RCB_2025_Squad (
    PlayerID INT ,
    PlayerName STRING ,
    Role STRING,
    Nationality STRING,
    Age INT
);
INSERT INTO RCB_2025_Squad (PlayerID, PlayerName, Role, Nationality, Age) VALUES
(1, 'Rajat Patidar', 'Batter', 'India', 31),
(2, 'Virat Kohli', 'Batter', 'India', 36),
(3, 'Phil Salt', 'WK-Batter', 'England', 28),
(4, 'Jitesh Sharma', 'WK-Batter', 'India', 31),
(5, 'Swastik Chhikara', 'Batter', 'India', 19),
(6, 'Tim Seifert', 'WK-Batter', 'New Zealand', 29),
(7, 'Mayank Agarwal', 'Batter', 'India', 33),
(8, 'Liam Livingstone', 'All-Rounder', 'England', 32),
(9, 'Krunal Pandya', 'All-Rounder', 'India', 34),
(10, 'Swapnil Singh', 'All-Rounder', 'India', 33),
(11, 'Tim David', 'All-Rounder', 'Australia', 28),
(12, 'Romario Shepherd', 'All-Rounder', 'West Indies', 30),
(13, 'Manoj Bhandage', 'All-Rounder', 'India', 26),
(14, 'Blessing Muzarabani', 'Bowler', 'Zimbabwe', 28),
(15, 'Josh Hazlewood', 'Bowler', 'Australia', 34),
(16, 'Rasikh Dar', 'Bowler', 'India', 25),
(17, 'Suyash Sharma', 'Bowler', 'India', 22),
(18, 'Bhuvneshwar Kumar', 'Bowler', 'India', 35),
(19, 'Nuwan Thushara', 'Bowler', 'Sri Lanka', 30),
(20, 'Lungisani Ngidi', 'Bowler', 'South Africa', 29),
(21, 'Abhinandan Singh', 'Bowler', 'India', 24),
(22, 'Mohit Rathee', 'Bowler', 'India', 26),
(23, 'Yash Dayal', 'Bowler', 'India', 26);



select*from rcb_2025_squad;


INSERT INTO RCB_2025_Squad (PlayerID, PlayerName, Role, Nationality, Age)
VALUES
  (1, 'Faf du Plessis', 'Middle-order Batter', 'South Africa', 39),
  (2, 'Anuj Rawat', 'Wicketkeeper Batter', 'India', 24),
  (3, 'Saurav Chauhan', 'Top-order Batter', 'India', 23),
  (4, 'Dinesh Karthik', 'Wicketkeeper Batter', 'India', 38),
  (5, 'Tom Curran', 'All-rounder', 'England', 28),
  (6, 'Glenn Maxwell', 'All-rounder', 'Australia', 35),
  (7, 'Cameron Green', 'All-rounder', 'Australia', 24),
  (8, 'Mahipal Lomror', 'All-rounder', 'India', 24),
  (9, 'Mayank Dagar', 'All-rounder', 'India', 26),
  (10, 'Lockie Ferguson', 'Bowler', 'New Zealand', 32),
  (11, 'Mohammed Siraj', 'Bowler', 'India', 29),
  (12, 'Akash Deep', 'Bowler', 'India', 27),
  (13, 'Reece Topley', 'Bowler', 'England', 29),
  (14, 'Himanshu Sharma', 'Bowler', 'India', 25),
  (15, 'Karn Sharma', 'Bowler', 'India', 36),
  (16, 'Yash Dayal', 'Bowler', 'India', 26);
